# %%
from gurobipy import *

# %%
milp_model = Model("milp")
# Out:
# Restricted license - for non-production use only - expires 2027-11-29

# %%
# # Gurobi WLS license file
# # Your credentials are private and should not be shared or copied to public repositories.
# # Visit https://license.gurobi.com/manager/doc/overview for more information.



import gurobipy as gp

# <<< REPLACE WITH YOUR REAL VALUES (as strings) >>>
ACCESS_ID = "Your ID"   # string!
SECRET    = "Your Secret Code"   # string!
LICENSEID = "Your License ID"                                # string is safest

# Quick type check (optional)
assert isinstance(ACCESS_ID, str) and isinstance(SECRET, str) and isinstance(LICENSEID, (str, int))

env = gp.Env(empty=True)
env.setParam("WLSACCESSID", str(ACCESS_ID))
env.setParam("WLSSECRET",   str(SECRET))
env.setParam("LICENSEID",   LICENSEID)   # pass as string to be safe
# env.setParam("WLSSERVER", "https://license.gurobi.com")  # optional
env.start()

# smoke test
m = gp.Model("ping", env=env)
x = m.addVar(ub=1.0)
m.setObjective(x, gp.GRB.MAXIMIZE)
m.optimize()
print("Gurobi OK, x =", x.X)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2783276
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 0 rows, 1 columns and 0 nonzeros (Max)
# Model fingerprint: 0x5939e866
# Model has 1 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi OK, x = 1.0

# %%
import re
from typing import Dict, Tuple, Optional, Iterable
import gurobipy as gp

# ----------------- bit helpers -----------------
def rotl(bits, r: int):
    n = len(bits); r %= n
    return [bits[(i - r) % n] for i in range(n)]

def rotr(bits, r: int):
    n = len(bits); r %= n
    return [bits[(i + r) % n] for i in range(n)]

def bits_from_word(m: gp.Model, name: str, nbits: int):
    return [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}[{i}]") for i in range(nbits)]

# def add_word(m: gp.Model, x, y, name: str):
#     """Mod-2^n add encoded exactly per bit: x + y + cin = z + 2*cout, cin=0."""
#     n = len(x)
#     z = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_z[{i}]") for i in range(n)]
#     c = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_c[{i}]") for i in range(n+1)]
#     m.addConstr(c[0] == 0, name=f"{name}_cin0")
#     for i in range(n):
#         m.addConstr(x[i] + y[i] + c[i] == z[i] + 2*c[i+1], name=f"{name}_fa[{i}]")
#     return z, c[1:]  # carry-outs c[1]..c[n] (c[n] is overflow)

def build_feasible_add_tuples():
    """
    Exact local XOR-differential feasibility tuples for one bit of
    z = x + y mod 2^n.

    Tuple format: (a, b, g, din, dout)
      a    = input diff bit on x
      b    = input diff bit on y
      g    = output diff bit on z
      din  = carry-difference into this bit
      dout = carry-difference out of this bit
    """
    feas = []

    def maj(u, v, w):
        return 1 if (u + v + w) >= 2 else 0

    for a in (0, 1):
        for b in (0, 1):
            for g in (0, 1):
                for din in (0, 1):
                    for dout in (0, 1):
                        ok = False
                        for x in (0, 1):
                            for y in (0, 1):
                                for cin in (0, 1):
                                    s  = x ^ y ^ cin
                                    co = maj(x, y, cin)

                                    xp   = x ^ a
                                    yp   = y ^ b
                                    cinp = cin ^ din
                                    sp   = xp ^ yp ^ cinp
                                    cop  = maj(xp, yp, cinp)

                                    if (s ^ sp) == g and (co ^ cop) == dout:
                                        ok = True
                                        break
                                if ok:
                                    break
                            if ok:
                                break
                        if ok:
                            feas.append((a, b, g, din, dout))
    return feas


FEAS_ADD_TUPLES = build_feasible_add_tuples()


def xor_diff_add_word_exact(m: gp.Model, a, b, name: str):
    """
    Exact XOR-differential feasibility model for modular addition.
    Returns:
      g  = output difference bits
      d  = carry-difference bits d[1]..d[n]
    """
    n = len(a)
    g = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_g[{i}]") for i in range(n)]
    d = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_d[{i}]") for i in range(n + 1)]

    # carry-difference into bit 0 is zero
    m.addConstr(d[0] == 0, name=f"{name}_d0")

    for i in range(n):
        lam = [
            m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_lam[{i},{k}]")
            for k in range(len(FEAS_ADD_TUPLES))
        ]

        # choose exactly one feasible local pattern
        m.addConstr(gp.quicksum(lam) == 1, name=f"{name}_onehot[{i}]")

        m.addConstr(
            a[i] == gp.quicksum(FEAS_ADD_TUPLES[k][0] * lam[k] for k in range(len(FEAS_ADD_TUPLES))),
            name=f"{name}_a[{i}]"
        )
        m.addConstr(
            b[i] == gp.quicksum(FEAS_ADD_TUPLES[k][1] * lam[k] for k in range(len(FEAS_ADD_TUPLES))),
            name=f"{name}_b[{i}]"
        )
        m.addConstr(
            g[i] == gp.quicksum(FEAS_ADD_TUPLES[k][2] * lam[k] for k in range(len(FEAS_ADD_TUPLES))),
            name=f"{name}_gmatch[{i}]"
        )
        m.addConstr(
            d[i] == gp.quicksum(FEAS_ADD_TUPLES[k][3] * lam[k] for k in range(len(FEAS_ADD_TUPLES))),
            name=f"{name}_din[{i}]"
        )
        m.addConstr(
            d[i + 1] == gp.quicksum(FEAS_ADD_TUPLES[k][4] * lam[k] for k in range(len(FEAS_ADD_TUPLES))),
            name=f"{name}_dout[{i}]"
        )

    # For mod 2^n addition, overflow difference d[n] is unconstrained.
    return g, d[1:]

def xor2_word(m: gp.Model, a, b, name: str):
    """Bitwise XOR via linearization: a + b = z + 2*(a&b)."""
    n = len(a)
    z = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_z[{i}]") for i in range(n)]
    t = [m.addVar(vtype=gp.GRB.BINARY, name=f"{name}_t[{i}]") for i in range(n)]
    for i in range(n):
        m.addConstr(t[i] <= a[i]); m.addConstr(t[i] <= b[i]); m.addConstr(t[i] >= a[i] + b[i] - 1)
        m.addConstr(a[i] + b[i] == z[i] + 2*t[i], name=f"{name}_xor[{i}]")
    return z

# --------------- MILP builder ----------------
def build_fha_milp(
    rounds: int = 6,
    nbits: int = 64,
    lanes: int = 8,
    ROT_A: Optional[Iterable[int]] = None,
    ROT_B: Optional[Iterable[int]] = None,
    ROT_G: Optional[Iterable[int]] = None,
    iterative: bool = True,
    pins: Optional[Dict[str, int]] = None,
    mode: str = "feas_le",                 # 'min' | 'feas_ge' | 'feas_le'
    target_weight: int = 255,              # used by feas modes
    cube_t0_bits: int = 0,                 # fix low bits of round-0 parity word t
    cube_t0_value: int = 0,                # value for the fixed bits
    threads: int = 1,
    timelimit: Optional[int] = None,
    env: Optional[gp.Env] = None,
) -> Tuple[gp.Model, gp.LinExpr]:
    """
    Builds (but does NOT optimize) the MILP for fha XOR-differentials.

    Returns: (model, W) where W is the linear expression for total carry weight
             (sum of carry-outs from all Mix-1 adds, overflow excluded).

    Pins expect keys like 'L0_0', 'R0_0' (side L/R, lane index, round index).
    """
    # FHA rotations (mod word size). lanes=8 = ARX lanes inside F.
    if ROT_A is None: ROT_A = [63,19,39,15,23,31,11,5]
    if ROT_B is None: ROT_B = [21, 3,31,33,45, 5,17,7]
    if ROT_G is None: ROT_G = [25,45,51, 5,63,47, 7,1]
    ROT_A = list(ROT_A); ROT_B = list(ROT_B); ROT_G = list(ROT_G)
    if len(ROT_A) < lanes: ROT_A = (ROT_A * ((lanes + len(ROT_A)-1)//len(ROT_A)))[:lanes]
    if len(ROT_B) < lanes: ROT_B = (ROT_B * ((lanes + len(ROT_B)-1)//len(ROT_B)))[:lanes]
    if len(ROT_G) < lanes: ROT_G = (ROT_G * ((lanes + len(ROT_G)-1)//len(ROT_G)))[:lanes]

    m = gp.Model("fha_xordiff", env=env) if env else gp.Model("fha_xordiff")
    if threads:   m.Params.Threads   = threads
    if timelimit: m.Params.TimeLimit = timelimit

    # # Helpful default knobs
    # m.Params.MIPFocus       = 2      # focus on proving (incl. infeasibility)
    # m.Params.Heuristics     = 0.05   # spend less time on heuristics
    # m.Params.Cuts           = 3      # more aggressive global cuts
    # m.Params.CutPasses      = 3
    # m.Params.ImpliedCuts    = 2
    # m.Params.LiftProjectCuts= 2
    # m.Params.FlowCoverCuts  = 2
    # # m.Params.GomoryCuts     = 2
    # m.Params.Presolve       = 2
    # m.Params.PrePasses      = 10
    # m.Params.PreSparsify    = 1
    # m.Params.Symmetry       = 2
    # # Long runs: tree spill to disk (prevents slowdown)
    # m.Params.NodefileStart  = 4      # GB
    # m.Params.NodefileDir    = "/tmp" # fast SSD path
    # # m.Params.NodefileCompress = 1

    # State words: L[j][i], R[j][i] as bit arrays
    L = [[bits_from_word(m, f"L{j}_{i}", nbits) for i in range(rounds+1)] for j in range(lanes)]
    R = [[bits_from_word(m, f"R{j}_{i}", nbits) for i in range(rounds+1)] for j in range(lanes)]

    # Prevent the trivial all-zero trail
    init_diff = gp.quicksum(
        L[j][0][b] + R[j][0][b]
        for j in range(lanes)
        for b in range(nbits)
    )
    m.addConstr(init_diff >= 1, name="nontrivial_init")

    weight_bits = []  # collects carry bits (excluding final overflow) from Mix-1 adds

    for i in range(rounds):
        # 1) L_{i+1} = R_i
        for j in range(lanes):
            for b in range(nbits):
                m.addConstr(L[j][i+1][b] == R[j][i][b], name=f"copy_L[{j},{i},{b}]")

        # 2) F(R_i): Mix-1 (ADD), Mix-2 (XOR with ROTR), RC dropped in diff model, t parity, output mix with ROTL(t)
        V1, V2, V3 = [[] for _ in range(lanes)], [[] for _ in range(lanes)], [[] for _ in range(lanes)]
        for j in range(lanes):
            j1, j2 = (j+1) % lanes, (j+2) % lanes
            # v1 = R[j] + ROTL(R[j1], ROT_A[j])
            # z1, carries = xor_diff_add_word_exact(m, R[j][i], rotl(R[j1][i], ROT_A[j] % nbits), f"add_{i}_{j}")
            # V1[j] = z1
            # if carries:
            #     weight_bits += carries[:-1] 
            z1, carrydiffs = xor_diff_add_word_exact(
                m,
                R[j][i],
                rotl(R[j1][i], ROT_A[j] % nbits),
                f"add_{i}_{j}"
            )
            V1[j] = z1
            if carrydiffs:
                weight_bits += carrydiffs[:-1]   # keep as carry-activity proxy # exclude overflow carry
            # v2 = v1 XOR ROTR(R[j2], ROT_B[j])
            V2[j] = xor2_word(m, V1[j], rotr(R[j2][i], ROT_B[j] % nbits), f"xor2_{i}_{j}")
            V3[j] = V2[j]  # RC addition is dropped (XOR-diff neutral under this conservative relaxation)

        # t = XOR over lanes of V3[j]
        t = V3[0]
        for j in range(1, lanes):
            t = xor2_word(m, t, V3[j], f"tacc_{i}_{j}")

        # cubing hook: fix low bits of t at round 0
        if i == 0 and cube_t0_bits > 0:
            for b in range(cube_t0_bits):
                bitval = (cube_t0_value >> b) & 1
                t[b].LB = bitval
                t[b].UB = bitval

        # fo[j] = v3[j] XOR ROTL(t, ROT_G[j])
        FO = [None] * lanes
        for j in range(lanes):
            FO[j] = xor2_word(m, V3[j], rotl(t, ROT_G[j] % nbits), f"fo_{i}_{j}")

        # 3) R_{i+1} = L_i XOR FO
        for j in range(lanes):
            R[j][i+1] = xor2_word(m, L[j][i], FO[j], f"Rnext_{i}_{j}")

    # Iterative trail: (L0,R0) == (Lr,Rr)
    if iterative:
        for j in range(lanes):
            for b in range(nbits):
                m.addConstr(L[j][0][b] == L[j][rounds][b], name=f"iter_L[{j},{b}]")
                m.addConstr(R[j][0][b] == R[j][rounds][b], name=f"iter_R[{j},{b}]")

    # Two-lane pinning (symmetry breaking)
    if pins:
        for key, val in pins.items():
            mobj = re.fullmatch(r'([LR])(\d+)_(\d+)', key)
            if not mobj:
                raise ValueError(f"Bad pin key: {key}")
            side, jj, rnd = mobj.group(1), int(mobj.group(2)), int(mobj.group(3))
            word = L[jj][rnd] if side == 'L' else R[jj][rnd]
            for b in range(nbits):
                bit = (val >> b) & 1
                word[b].LB = bit
                word[b].UB = bit

    # Objective / feasibility
    W = gp.quicksum(weight_bits)
    if mode == "min":
        m.setObjective(W, gp.GRB.MINIMIZE)
    elif mode == "feas_ge":
        m.addConstr(W >= target_weight, name="W_ge")
        m.setObjective(0, gp.GRB.MINIMIZE)
    elif mode == "feas_le":
        m.addConstr(W <= target_weight, name="W_le")
        m.setObjective(0, gp.GRB.MINIMIZE)
    else:
        raise ValueError("mode must be 'min' | 'feas_ge' | 'feas_le'")

    return m, W

# %% [markdown]
# # Reproducibility notebook for FHA-Perm differential MILP results
#
# This notebook reproduces the reduced-round XOR-differential MILP experiments reported in Section 5.6 of the paper.
# Configuration used here:
# - n = 64
# - lanes = 8
# - round constants omitted
# - non-iterative sparse trails
# - single-bit / single-lane pinned input pattern
# - feasibility target W <= 512

# %%
# Paper reproduction: Section 5.6
# Attacker-favouring relaxation:
# - round constants omitted
# - non-iterative trails
# - single-bit / single-lane sparse input pattern

nbits = 64
seed = 1 << (nbits - 1)

for r in [1, 2, 3, 4, 5, 6]:
    print(f"\n=== rounds={r} ===")
    m, W = build_fha_milp(
        rounds=r,
        nbits=nbits,
        lanes=8,
        iterative=False,
        pins={"L0_0": 0x0, "R0_0": seed},
        mode="feas_le",
        target_weight=512,
        env=env,
        # timelimit=YOUR_TIME_LIMITS.get(r, None),
        threads=8
    )

    m.Params.MIPFocus = 2
    m.Params.Heuristics = 0.0
    m.Params.Cuts = 2
    m.Params.Presolve = 2
    m.optimize()

    print("Status:", m.Status, "SolCount:", m.SolCount, "Runtime:", m.Runtime)


if m.SolCount > 0:
    print("FOUND: there exists a trail with W <= 512 (under this model/restrictions).")
elif m.Status == gp.GRB.INFEASIBLE:
    print("PROVED: no trail with W <= 512 (minW >= 512) under this model/restrictions.")
elif m.Status == gp.GRB.TIME_LIMIT:
    print("UNKNOWN: time limit.")
else:
    print("Status:", m.Status, "(unknown/other).")
# Out:
# === rounds=1 ===
# Set parameter Threads to value 8
# Set parameter MIPFocus to value 2
# Set parameter Heuristics to value 0
# Set parameter Cuts to value 2
# Set parameter Presolve to value 2
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# Heuristics  0
# MIPFocus  2
# Cuts  2
# Presolve  2
# Threads  8
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 11530 rows, 14216 columns and 52032 nonzeros (Min)
# Model fingerprint: 0x09ac57a6
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 14216 integer (14216 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Presolve removed 9057 rows and 7544 columns
# Presolve time: 0.25s
# Presolved: 2473 rows, 6672 columns, 19987 nonzeros
# Variable types: 0 continuous, 6672 integer (6672 binary)
# Root relaxation presolve removed 2473 rows and 6672 columns
# Root relaxation presolve: All rows and columns removed
#
# Root relaxation: objective 0.000000e+00, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.26 seconds (0.49 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Status: 2 SolCount: 1 Runtime: 0.2610769271850586
#
# === rounds=2 ===
# Set parameter Threads to value 8
# Set parameter MIPFocus to value 2
# Set parameter Heuristics to value 0
# Set parameter Cuts to value 2
# Set parameter Presolve to value 2
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# Heuristics  0
# MIPFocus  2
# Cuts  2
# Presolve  2
# Threads  8
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 23058 rows, 27408 columns and 103040 nonzeros (Min)
# Model fingerprint: 0x9a458ad1
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 27408 integer (27408 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Presolve removed 13625 rows and 12072 columns
# Presolve time: 0.51s
# Presolved: 9433 rows, 15336 columns, 62423 nonzeros
# Variable types: 0 continuous, 15336 integer (15336 binary)
# Root relaxation presolve removed 1664 rows and 128 columns
# Root relaxation presolved: 7769 rows, 16744 columns, 56803 nonzeros
#
#
# Root relaxation: objective 0.000000e+00, 2978 iterations, 0.35 seconds (0.66 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  322          -    0.00000      -     -    1s
#      0     0    0.00000    0  463          -    0.00000      -     -    1s
#      0     0    0.00000    0  584          -    0.00000      -     -    1s
#      0     0    0.00000    0  976          -    0.00000      -     -    2s
# *    0     0               0       0.0000000    0.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 11
#   Zero half: 14
#
# Explored 1 nodes (22148 simplex iterations) in 3.57 seconds (5.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Status: 2 SolCount: 1 Runtime: 3.570927143096924
#
# === rounds=3 ===
# Set parameter Threads to value 8
# Set parameter MIPFocus to value 2
# Set parameter Heuristics to value 0
# Set parameter Cuts to value 2
# Set parameter Presolve to value 2
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# Heuristics  0
# MIPFocus  2
# Cuts  2
# Presolve  2
# Threads  8
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 34586 rows, 40600 columns and 154048 nonzeros (Min)
# Model fingerprint: 0xc69b1c77
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 40600 integer (40600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Presolve removed 14417 rows and 16416 columns
# Presolve time: 0.85s
# Presolved: 20169 rows, 24184 columns, 117791 nonzeros
# Variable types: 0 continuous, 24184 integer (24184 binary)
# Root relaxation presolve removed 4224 rows and 128 columns
# Root relaxation presolved: 15945 rows, 28152 columns, 104491 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.41s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 3967 iterations, 0.91 seconds (1.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    2s
#
# Explored 1 nodes (9589 simplex iterations) in 2.23 seconds (3.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Status: 2 SolCount: 1 Runtime: 2.2337121963500977
#
# === rounds=4 ===
# Set parameter Threads to value 8
# Set parameter MIPFocus to value 2
# Set parameter Heuristics to value 0
# Set parameter Cuts to value 2
# Set parameter Presolve to value 2
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# Heuristics  0
# MIPFocus  2
# Cuts  2
# Presolve  2
# Threads  8
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 46114 rows, 53792 columns and 205056 nonzeros (Min)
# Model fingerprint: 0x0ce37893
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 53792 integer (53792 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Presolve removed 14953 rows and 20760 columns
# Presolve time: 1.27s
# Presolved: 31161 rows, 33032 columns, 174439 nonzeros
# Variable types: 0 continuous, 33032 integer (33032 binary)
# Root relaxation presolve removed 7040 rows and 128 columns
# Root relaxation presolved: 24121 rows, 39816 columns, 152691 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    21976    0.0000000e+00   2.461521e+01   2.522769e+10      5s
#    30660    0.0000000e+00   6.451177e-03   2.365581e+09     10s
# Warning: Markowitz tolerance tightened to 0.25
#    30877    0.0000000e+00   0.000000e+00   0.000000e+00     10s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#    30877    0.0000000e+00   0.000000e+00   0.000000e+00     10s
#
# Root relaxation: objective 0.000000e+00, 30877 iterations, 9.00 seconds (11.50 work units)
#
# Interrupt request received
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 8320          -    0.00000      -     -   25s
#
# Explored 1 nodes (57093 simplex iterations) in 25.27 seconds (33.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Solve interrupted
# Best objective -, best bound 0.000000000000e+00, gap -
# Status: 11 SolCount: 0 Runtime: 25.279726028442383
#
# === rounds=5 ===
# Set parameter Threads to value 8
# Set parameter MIPFocus to value 2
# Set parameter Heuristics to value 0
# Set parameter Cuts to value 2
# Set parameter Presolve to value 2
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# Heuristics  0
# MIPFocus  2
# Cuts  2
# Presolve  2
# Threads  8
#
# Academic license 2783276 - for non-commercial use only - registered to ro___@gmail.com
# Optimize a model with 57642 rows, 66984 columns and 256064 nonzeros (Min)
# Model fingerprint: 0xaa6b5c52
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 66984 integer (66984 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Presolve removed 15489 rows and 25104 columns
# Presolve time: 1.13s
# Presolved: 42153 rows, 41880 columns, 231087 nonzeros
# Variable types: 0 continuous, 41880 integer (41880 binary)
# Root relaxation presolve removed 9856 rows and 128 columns
# Root relaxation presolved: 32297 rows, 51480 columns, 200891 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    22880    0.0000000e+00   1.725345e+02   5.253108e+10      5s
#    33278    0.0000000e+00   4.860864e+01   5.945294e+10     10s
